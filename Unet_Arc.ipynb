# %% [markdown]
# <a href="https://colab.research.google.com/github/deha388/unet/blob/master/Unet_Arc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import os
import random
import numpy as np
from tqdm import tqdm 
from skimage.io import imread, imshow
from skimage.transform import resize
import matplotlib.pyplot as plt
import os, sys
from PIL import Image
import cv2
from keras.callbacks import EarlyStopping, ModelCheckpoint
import glob
from scipy import misc
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

import tensorflow as tf

# %%
seed = 42
np.random.seed = seed

IMG_WIDTH = 512
IMG_HEIGHT = 512
IMG_CHANNELS = 3

M_PATH = 'drive/My Drive/drone_train1/'
TRAIN_PATH = 'drive/My Drive/drone_train2/'
TEST_PATH = 'drive/My Drive/drone_test/'

train_ids = next(os.walk(TRAIN_PATH))[1]
test_ids = next(os.walk(TEST_PATH))[1]

X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)

# %%
print('Resizing training images and masks')
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):   
    path = TRAIN_PATH +id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]  
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_train[n] = img  #Fill empty X_train with values from img
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)            
    for mask_file in next(os.walk(path + '/masks/'))[2]:
        mask_ = imread(path + '/masks/' + mask_file)
        mask_ = np.expand_dims(resize(mask_, (IMG_HEIGHT, IMG_WIDTH), mode='constant',  
                                      preserve_range=True), axis=-1)
        mask = np.maximum(mask, mask_)  
        # CY: Bu üst satırda tam olarak ne yapılıyor?
            
    Y_train[n] = mask
# Out:
#   0%|          | 0/211 [00:00<?, ?it/s]
# Resizing training images and masks
# 100%|██████████| 211/211 [13:47<00:00,  3.92s/it]

# %%
X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
sizes_test = []
print('Resizing test images') 
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
    path = TEST_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    sizes_test.append([img.shape[0], img.shape[1]])
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_test[n] = img

print('Done!')
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Resizing test images
# 100%|██████████| 10/10 [01:08<00:00,  6.82s/it]
# Done!

# %%
image_x = random.randint(0, len(train_ids))

imshow(X_train[image_x])
plt.show()
imshow(np.squeeze(Y_train[image_x]))
plt.show()

# %%
for i in range(3):
  ix = random.randint(0, len(test_ids))
  imshow(X_test[ix])
  plt.show()
  imshow(np.squeeze(X_test[ix]))
  plt.show()

# %%
inputs = tf.keras.layers.Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = tf.keras.layers.Lambda(lambda x: x / 255)(inputs)

#encode
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
c1 = tf.keras.layers.Dropout(0.1)(c1)
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
p1 = tf.keras.layers.MaxPooling2D((2, 2))(c1)

c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
c2 = tf.keras.layers.Dropout(0.1)(c2)
c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
p2 = tf.keras.layers.MaxPooling2D((2, 2))(c2)
 
c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
c3 = tf.keras.layers.Dropout(0.2)(c3)
c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
p3 = tf.keras.layers.MaxPooling2D((2, 2))(c3)
 
c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
c4 = tf.keras.layers.Dropout(0.2)(c4)
c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
p4 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(c4)
 
c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
c5 = tf.keras.layers.Dropout(0.3)(c5)
c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)
p5 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(c5)

c6 = tf.keras.layers.Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p5)
c6 = tf.keras.layers.Dropout(0.3)(c6)
c6 = tf.keras.layers.Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)

#decode 

u7 = tf.keras.layers.Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(c6)
u7 = tf.keras.layers.concatenate([u7, c5])
c7 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
c7 = tf.keras.layers.Dropout(0.2)(c7)
c7 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)
 
u8 = tf.keras.layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c7)
u8 = tf.keras.layers.concatenate([u8, c4])
c8 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
c8 = tf.keras.layers.Dropout(0.2)(c8)
c8 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)
 
u9 = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c8)
u9 = tf.keras.layers.concatenate([u9, c3])
c9 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
c9 = tf.keras.layers.Dropout(0.1)(c9)
c9 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)
 
u10 = tf.keras.layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c9)
u10 = tf.keras.layers.concatenate([u10, c2], axis=3)
c10 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u10)
c10 = tf.keras.layers.Dropout(0.1)(c10)
c10 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c10)

u11 = tf.keras.layers.Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c10)
u11 = tf.keras.layers.concatenate([u11, c1], axis=3)
c11 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u11)
c11 = tf.keras.layers.Dropout(0.1)(c11)
c11 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c11)
 
outputs = tf.keras.layers.Conv2D(1, (1, 1), activation='sigmoid')(c11)
 
model = tf.keras.Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 512, 512, 3) 0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 512, 512, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 512, 512, 16) 448         lambda_1[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 512, 512, 16) 0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 512, 512, 16) 2320        dropout_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 256, 256, 16) 0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 256, 256, 32) 4640        max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 256, 256, 32) 0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 256, 256, 32) 9248        dropout_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 128, 128, 32) 0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 128, 128, 64) 18496       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 128, 128, 64) 0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 128, 128, 64) 36928       dropout_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 64, 64, 64)   0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 64, 64, 128)  73856       max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 64, 64, 128)  0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 64, 64, 128)  147584      dropout_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 32, 32, 128)  0           conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 32, 32, 256)  295168      max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 32, 32, 256)  0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 32, 32, 256)  590080      dropout_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 16, 16, 256)  0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 16, 16, 512)  1180160     max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 16, 16, 512)  0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 16, 16, 512)  2359808     dropout_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 32, 32, 256)  524544      conv2d_34[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 32, 32, 512)  0           conv2d_transpose_5[0][0]
#                                                                  conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 32, 32, 256)  1179904     concatenate_5[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 32, 32, 256)  0           conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 32, 32, 256)  590080      dropout_17[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 64, 64, 128)  131200      conv2d_36[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 64, 64, 256)  0           conv2d_transpose_6[0][0]
#                                                                  conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 64, 64, 128)  295040      concatenate_6[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 64, 64, 128)  0           conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 64, 64, 128)  147584      dropout_18[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 128, 128, 64) 32832       conv2d_38[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 128, 128, 128 0           conv2d_transpose_7[0][0]
#                                                                  conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 128, 128, 64) 73792       concatenate_7[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 128, 128, 64) 0           conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 128, 128, 64) 36928       dropout_19[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 256, 256, 32) 8224        conv2d_40[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 256, 256, 64) 0           conv2d_transpose_8[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 256, 256, 32) 18464       concatenate_8[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 256, 256, 32) 0           conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 256, 256, 32) 9248        dropout_20[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 512, 512, 16) 2064        conv2d_42[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 512, 512, 32) 0           conv2d_transpose_9[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 512, 512, 16) 4624        concatenate_9[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 512, 512, 16) 0           conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 512, 512, 16) 2320        dropout_21[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 512, 512, 1)  17          conv2d_44[0][0]
# ==================================================================================================
# Total params: 7,775,601
# Trainable params: 7,775,601
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
earlystopper = tf.keras.callbacks.EarlyStopping(patience=5, monitor='val_loss')
checkpointer = tf.keras.callbacks.ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
results = model.fit(X_train, Y_train, validation_split=0.01, batch_size=16, epochs=50,
                    callbacks=[earlystopper, checkpointer])




print('Done!')
# Out:
# Epoch 1/50
# 13/13 [==============================] - ETA: 0s - loss: 0.6827 - accuracy: 0.6006
# Epoch 00001: val_loss improved from inf to 0.67316, saving model to model.h5
# 13/13 [==============================] - 11s 810ms/step - loss: 0.6827 - accuracy: 0.6006 - val_loss: 0.6732 - val_accuracy: 0.5297
# Epoch 2/50
# 13/13 [==============================] - ETA: 0s - loss: 0.5621 - accuracy: 0.6685
# Epoch 00002: val_loss improved from 0.67316 to 0.51380, saving model to model.h5
# 13/13 [==============================] - 10s 787ms/step - loss: 0.5621 - accuracy: 0.6685 - val_loss: 0.5138 - val_accuracy: 0.8501
# Epoch 3/50
# 13/13 [==============================] - ETA: 0s - loss: 0.4744 - accuracy: 0.7743
# Epoch 00003: val_loss improved from 0.51380 to 0.45584, saving model to model.h5
# 13/13 [==============================] - 10s 789ms/step - loss: 0.4744 - accuracy: 0.7743 - val_loss: 0.4558 - val_accuracy: 0.8446
# Epoch 4/50
# 13/13 [==============================] - ETA: 0s - loss: 0.4490 - accuracy: 0.7923
# Epoch 00004: val_loss improved from 0.45584 to 0.42759, saving model to model.h5
# 13/13 [==============================] - 10s 789ms/step - loss: 0.4490 - accuracy: 0.7923 - val_loss: 0.4276 - val_accuracy: 0.8487
# Epoch 5/50
# 13/13 [==============================] - ETA: 0s - loss: 0.4269 - accuracy: 0.8097
# Epoch 00005: val_loss improved from 0.42759 to 0.39703, saving model to model.h5
# 13/13 [==============================] - 10s 791ms/step - loss: 0.4269 - accuracy: 0.8097 - val_loss: 0.3970 - val_accuracy: 0.8696
# Epoch 6/50
# 13/13 [==============================] - ETA: 0s - loss: 0.4233 - accuracy: 0.8110
# Epoch 00006: val_loss improved from 0.39703 to 0.38881, saving model to model.h5
# 13/13 [==============================] - 10s 793ms/step - loss: 0.4233 - accuracy: 0.8110 - val_loss: 0.3888 - val_accuracy: 0.8743
# Epoch 7/50
# 13/13 [==============================] - ETA: 0s - loss: 0.3929 - accuracy: 0.8284
# Epoch 00007: val_loss improved from 0.38881 to 0.35003, saving model to model.h5
# 13/13 [==============================] - 10s 795ms/step - loss: 0.3929 - accuracy: 0.8284 - val_loss: 0.3500 - val_accuracy: 0.8754
# Epoch 8/50
# 13/13 [==============================] - ETA: 0s - loss: 0.3854 - accuracy: 0.8335
# Epoch 00008: val_loss improved from 0.35003 to 0.33346, saving model to model.h5
# 13/13 [==============================] - 10s 801ms/step - loss: 0.3854 - accuracy: 0.8335 - val_loss: 0.3335 - val_accuracy: 0.8795
# Epoch 9/50
# 13/13 [==============================] - ETA: 0s - loss: 0.3868 - accuracy: 0.8393
# Epoch 00009: val_loss did not improve from 0.33346
# 13/13 [==============================] - 10s 783ms/step - loss: 0.3868 - accuracy: 0.8393 - val_loss: 0.3794 - val_accuracy: 0.8729
# Epoch 10/50
# 13/13 [==============================] - ETA: 0s - loss: 0.3724 - accuracy: 0.8429
# Epoch 00010: val_loss improved from 0.33346 to 0.33240, saving model to model.h5
# 13/13 [==============================] - 10s 799ms/step - loss: 0.3724 - accuracy: 0.8429 - val_loss: 0.3324 - val_accuracy: 0.8757
# Epoch 11/50
# 13/13 [==============================] - ETA: 0s - loss: 0.3644 - accuracy: 0.8462
# Epoch 00011: val_loss did not improve from 0.33240
# 13/13 [==============================] - 10s 779ms/step - loss: 0.3644 - accuracy: 0.8462 - val_loss: 0.3326 - val_accuracy: 0.8761
# Epoch 12/50
# 13/13 [==============================] - ETA: 0s - loss: 0.3607 - accuracy: 0.8520
# Epoch 00012: val_loss did not improve from 0.33240
# 13/13 [==============================] - 10s 779ms/step - loss: 0.3607 - accuracy: 0.8520 - val_loss: 0.3331 - val_accuracy: 0.8811
# Epoch 13/50
# 13/13 [==============================] - ETA: 0s - loss: 0.3637 - accuracy: 0.8445
# Epoch 00013: val_loss improved from 0.33240 to 0.32556, saving model to model.h5
# 13/13 [==============================] - 10s 805ms/step - loss: 0.3637 - accuracy: 0.8445 - val_loss: 0.3256 - val_accuracy: 0.8754
# Epoch 14/50
# 13/13 [==============================] - ETA: 0s - loss: 0.3734 - accuracy: 0.8373
# Epoch 00014: val_loss did not improve from 0.32556
# 13/13 [==============================] - 10s 787ms/step - loss: 0.3734 - accuracy: 0.8373 - val_loss: 0.3372 - val_accuracy: 0.8784
# Epoch 15/50
# 13/13 [==============================] - ETA: 0s - loss: 0.3460 - accuracy: 0.8563
# Epoch 00015: val_loss improved from 0.32556 to 0.31148, saving model to model.h5
# 13/13 [==============================] - 10s 807ms/step - loss: 0.3460 - accuracy: 0.8563 - val_loss: 0.3115 - val_accuracy: 0.8791
# Epoch 16/50
# 13/13 [==============================] - ETA: 0s - loss: 0.3405 - accuracy: 0.8610
# Epoch 00016: val_loss improved from 0.31148 to 0.30037, saving model to model.h5
# 13/13 [==============================] - 10s 806ms/step - loss: 0.3405 - accuracy: 0.8610 - val_loss: 0.3004 - val_accuracy: 0.8785
# Epoch 17/50
# 13/13 [==============================] - ETA: 0s - loss: 0.3304 - accuracy: 0.8615
# Epoch 00017: val_loss improved from 0.30037 to 0.29398, saving model to model.h5
# 13/13 [==============================] - 10s 803ms/step - loss: 0.3304 - accuracy: 0.8615 - val_loss: 0.2940 - val_accuracy: 0.8820
# Epoch 18/50
# 13/13 [==============================] - ETA: 0s - loss: 0.3264 - accuracy: 0.8624
# Epoch 00018: val_loss improved from 0.29398 to 0.29193, saving model to model.h5
# 13/13 [==============================] - 10s 803ms/step - loss: 0.3264 - accuracy: 0.8624 - val_loss: 0.2919 - val_accuracy: 0.8801
# Epoch 19/50
# 13/13 [==============================] - ETA: 0s - loss: 0.3253 - accuracy: 0.8655
# Epoch 00019: val_loss improved from 0.29193 to 0.28152, saving model to model.h5
# 13/13 [==============================] - 10s 803ms/step - loss: 0.3253 - accuracy: 0.8655 - val_loss: 0.2815 - val_accuracy: 0.8782
# Epoch 20/50
# 13/13 [==============================] - ETA: 0s - loss: 0.3050 - accuracy: 0.8771
# Epoch 00020: val_loss improved from 0.28152 to 0.26233, saving model to model.h5
# 13/13 [==============================] - 10s 802ms/step - loss: 0.3050 - accuracy: 0.8771 - val_loss: 0.2623 - val_accuracy: 0.8887
# Epoch 21/50
# 13/13 [==============================] - ETA: 0s - loss: 0.3218 - accuracy: 0.8649
# Epoch 00021: val_loss did not improve from 0.26233
# 13/13 [==============================] - 10s 782ms/step - loss: 0.3218 - accuracy: 0.8649 - val_loss: 0.3001 - val_accuracy: 0.8724
# Epoch 22/50
# 13/13 [==============================] - ETA: 0s - loss: 0.3176 - accuracy: 0.8709
# Epoch 00022: val_loss did not improve from 0.26233
# 13/13 [==============================] - 10s 788ms/step - loss: 0.3176 - accuracy: 0.8709 - val_loss: 0.2654 - val_accuracy: 0.8891
# Epoch 23/50
# 13/13 [==============================] - ETA: 0s - loss: 0.3177 - accuracy: 0.8641
# Epoch 00023: val_loss did not improve from 0.26233
# 13/13 [==============================] - 10s 789ms/step - loss: 0.3177 - accuracy: 0.8641 - val_loss: 0.2963 - val_accuracy: 0.8803
# Epoch 24/50
# 13/13 [==============================] - ETA: 0s - loss: 0.3079 - accuracy: 0.8736
# Epoch 00024: val_loss improved from 0.26233 to 0.25504, saving model to model.h5
# 13/13 [==============================] - 11s 810ms/step - loss: 0.3079 - accuracy: 0.8736 - val_loss: 0.2550 - val_accuracy: 0.8901
# Epoch 25/50
# 13/13 [==============================] - ETA: 0s - loss: 0.2855 - accuracy: 0.8849
# Epoch 00025: val_loss did not improve from 0.25504
# 13/13 [==============================] - 10s 782ms/step - loss: 0.2855 - accuracy: 0.8849 - val_loss: 0.2558 - val_accuracy: 0.8882
# Epoch 26/50
# 13/13 [==============================] - ETA: 0s - loss: 0.2747 - accuracy: 0.8893
# Epoch 00026: val_loss improved from 0.25504 to 0.25147, saving model to model.h5
# 13/13 [==============================] - 11s 808ms/step - loss: 0.2747 - accuracy: 0.8893 - val_loss: 0.2515 - val_accuracy: 0.8930
# Epoch 27/50
# 13/13 [==============================] - ETA: 0s - loss: 0.2920 - accuracy: 0.8790
# Epoch 00027: val_loss did not improve from 0.25147
# 13/13 [==============================] - 10s 784ms/step - loss: 0.2920 - accuracy: 0.8790 - val_loss: 0.2641 - val_accuracy: 0.8895
# Epoch 28/50
# 13/13 [==============================] - ETA: 0s - loss: 0.2878 - accuracy: 0.8828
# Epoch 00028: val_loss improved from 0.25147 to 0.24907, saving model to model.h5
# 13/13 [==============================] - 10s 807ms/step - loss: 0.2878 - accuracy: 0.8828 - val_loss: 0.2491 - val_accuracy: 0.8960
# Epoch 29/50
# 13/13 [==============================] - ETA: 0s - loss: 0.2935 - accuracy: 0.8789
# Epoch 00029: val_loss did not improve from 0.24907
# 13/13 [==============================] - 10s 782ms/step - loss: 0.2935 - accuracy: 0.8789 - val_loss: 0.2512 - val_accuracy: 0.8924
# Epoch 30/50
# 13/13 [==============================] - ETA: 0s - loss: 0.2905 - accuracy: 0.8828
# Epoch 00030: val_loss did not improve from 0.24907
# 13/13 [==============================] - 10s 789ms/step - loss: 0.2905 - accuracy: 0.8828 - val_loss: 0.2649 - val_accuracy: 0.8920
# Epoch 31/50
# 13/13 [==============================] - ETA: 0s - loss: 0.2696 - accuracy: 0.8907
# Epoch 00031: val_loss did not improve from 0.24907
# 13/13 [==============================] - 10s 791ms/step - loss: 0.2696 - accuracy: 0.8907 - val_loss: 0.2516 - val_accuracy: 0.8957
# Epoch 32/50
# 13/13 [==============================] - ETA: 0s - loss: 0.2716 - accuracy: 0.8898
# Epoch 00032: val_loss did not improve from 0.24907
# 13/13 [==============================] - 10s 788ms/step - loss: 0.2716 - accuracy: 0.8898 - val_loss: 0.2503 - val_accuracy: 0.8971
# Epoch 33/50
# 13/13 [==============================] - ETA: 0s - loss: 0.2701 - accuracy: 0.8903
# Epoch 00033: val_loss improved from 0.24907 to 0.24552, saving model to model.h5
# 13/13 [==============================] - 11s 808ms/step - loss: 0.2701 - accuracy: 0.8903 - val_loss: 0.2455 - val_accuracy: 0.8936
# Epoch 34/50
# 13/13 [==============================] - ETA: 0s - loss: 0.2646 - accuracy: 0.8917
# Epoch 00034: val_loss improved from 0.24552 to 0.24275, saving model to model.h5
# 13/13 [==============================] - 10s 807ms/step - loss: 0.2646 - accuracy: 0.8917 - val_loss: 0.2428 - val_accuracy: 0.9004
# Epoch 35/50
# 13/13 [==============================] - ETA: 0s - loss: 0.2550 - accuracy: 0.8959
# Epoch 00035: val_loss did not improve from 0.24275
# 13/13 [==============================] - 10s 783ms/step - loss: 0.2550 - accuracy: 0.8959 - val_loss: 0.2544 - val_accuracy: 0.8974
# Epoch 36/50
# 13/13 [==============================] - ETA: 0s - loss: 0.2589 - accuracy: 0.8929
# Epoch 00036: val_loss did not improve from 0.24275
# 13/13 [==============================] - 10s 787ms/step - loss: 0.2589 - accuracy: 0.8929 - val_loss: 0.3047 - val_accuracy: 0.8758
# Epoch 37/50
# 13/13 [==============================] - ETA: 0s - loss: 0.2596 - accuracy: 0.8947
# Epoch 00037: val_loss did not improve from 0.24275
# 13/13 [==============================] - 10s 789ms/step - loss: 0.2596 - accuracy: 0.8947 - val_loss: 0.2670 - val_accuracy: 0.9025
# Epoch 38/50
# 13/13 [==============================] - ETA: 0s - loss: 0.2520 - accuracy: 0.8958
# Epoch 00038: val_loss did not improve from 0.24275
# 13/13 [==============================] - 10s 790ms/step - loss: 0.2520 - accuracy: 0.8958 - val_loss: 0.2461 - val_accuracy: 0.8987
# Epoch 39/50
# 13/13 [==============================] - ETA: 0s - loss: 0.2499 - accuracy: 0.8991
# Epoch 00039: val_loss did not improve from 0.24275
# 13/13 [==============================] - 10s 789ms/step - loss: 0.2499 - accuracy: 0.8991 - val_loss: 0.2636 - val_accuracy: 0.8930
# Done!

# %%
preds_train = model.predict(X_train, verbose=1)
preds_val = model.predict(X_train, verbose=1)
preds_test = model.predict(X_test, verbose=1)

 
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
preds_test_t = (preds_test > 0.5).astype(np.uint8)
print('Done!')
# Out:
# 7/7 [==============================] - 5s 675ms/step
# 7/7 [==============================] - 3s 381ms/step
# 1/1 [==============================] - 0s 2ms/step
# Done!

# %%
model.evaluate(X_train, verbose=1)
# Out:
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00
# [0.0, 0.0]

# %%
# train data
ix = random.randint(0, len(preds_train_t))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()
imshow(np.squeeze(preds_train_t[ix]))
plt.show()
print('Done!')

# validation data
ix = 12
imshow(X_train[int(X_train.shape[0]*0.9):][ix])
plt.show()
imshow(np.squeeze(Y_train[int(Y_train.shape[0]*0.9):][ix]))
plt.show()
imshow(np.squeeze(preds_val_t[ix]))
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/io/_plugins/matplotlib_plugin.py:150: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)
# Done!

# %%
ix=1
imshow(X_test[ix])                    
plt.show()
imshow(np.squeeze(preds_test_t[ix]))
plt.show()
print('Done!')
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/io/_plugins/matplotlib_plugin.py:150: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)
# Done!
